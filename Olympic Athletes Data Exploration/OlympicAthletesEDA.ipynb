# %%
import pandas as pd
pd.set_option('display.max_colwidth', None, 'display.max_rows', 100, 'display.max_columns', 25)

# %% [markdown]
# # Clean The Bios FIle

# %%
bios = pd.read_csv('Olympics-Dataset/athletes/bios.csv')

# %%
bios.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                                Full name  \
# 0  François Joseph Marie Antoine "Jean-François"•Blanchy
# 1                                Arnaud Benjamin•Boetsch
# 2                            Jean Laurent Robert•Borotra
# 3                   Jacques Marie Stanislas Jean•Brugnon
# 4                                     Henry Albert•Canet
#
#                Used name  \
# 0  Jean-François•Blanchy
# 1         Arnaud•Boetsch
# 2           Jean•Borotra
# 3        Jacques•Brugnon
# 4           Albert•Canet
#
#                                                      Born  \
# 0             12 December 1886 in Bordeaux, Gironde (FRA)
# 1                  1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiques (FRA)
# 3                 11 May 1895 in Paris VIIIe, Paris (FRA)
# 4              17 April 1878 in Wandsworth, England (GBR)
#
#                                                               Died     NOC  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-Atlantiques (FRA)  France
# 1                                                              NaN  France
# 2              17 July 1994 in Arbonne, Pyrénées-Atlantiques (FRA)  France
# 3                            20 March 1978 in Monaco, Monaco (MON)  France
# 4                          25 July 1930 in Paris VIIe, Paris (FRA)  France
#
#    athlete_id    Measurements                         Affiliations  \
# 0           1             NaN                                  NaN
# 1           2  183 cm / 76 kg   Racing Club de France, Paris (FRA)
# 2           3  183 cm / 76 kg                     TCP, Paris (FRA)
# 3           4  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)
# 4           5             NaN                     TCP, Paris (FRA)
#
#                                 Nick/petnames Title(s) Other names  \
# 0                                         NaN      NaN         NaN
# 1                                         NaN      NaN         NaN
# 2  Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                        Toto      NaN         NaN
# 4                                         NaN      NaN         NaN
#
#   Nationality Original name Name order
# 0         NaN           NaN        NaN
# 1         NaN           NaN        NaN
# 2         NaN           NaN        NaN
# 3         NaN           NaN        NaN
# 4         NaN           NaN        NaN

# %% [markdown]
# ### What should we clean up?
# - [x] Get rid of bullet points in Used Name
# - [x] Split Measurements into Height and Weight
# - [x] Parse out date from `Born` & `Died` Column
# - [x] Parse out city, region, and country from `Born` Column
# - [x] Get rid of extra columns

# %%
df = bios.copy()

# %%
df.shape
# Out:
# (145500, 16)

# %% [markdown]
# ## Get rid of bullet points in Used Name

# %%
# Get rid of bullet points in Used Name
df['name'] = df['Used name'].str.replace('•',' ')

# %% [markdown]
# ## Split Measurements into Height and Weight

# %%
# Split the Measurements column into height & weight columns
df[['height_cm', 'weight_kg'] ]= df['Measurements'].str.split("/", expand=True)
df['weight_kg'].fillna(df['height_cm'], inplace=True) # This line fill same value if the data is null

# %%
# Make sure all values have pattern using '/'
df[~df['Measurements'].str.contains('/', na=False) & df['Measurements'].notna()][['Measurements', 'height_cm', 'weight_kg']].head()

## we can the issues bellow (index 165)
# Out:
#     Measurements height_cm weight_kg
# 87        178 cm    178 cm    178 cm
# 105       191 cm    191 cm    191 cm
# 165       120 kg    120 kg    120 kg
# 242       161 cm    161 cm    161 cm
# 243       161 cm    161 cm    161 cm

# %%
# Get rid of "cm" and the "kg" from our new columns
df['height_cm'] = pd.to_numeric(df['height_cm'].str.strip(' cm'), errors='coerce')
df['weight_kg'] = pd.to_numeric(df['weight_kg'].str.strip(' kg'), errors='coerce')
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations  \
# 0             NaN                                  NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)
# 2  183 cm / 76 kg                     TCP, Paris (FRA)
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)
# 4             NaN                     TCP, Paris (FRA)
#
#                                 Nick/petnames Title(s) Other names  \
# 0                                         NaN      NaN         NaN
# 1                                         NaN      NaN         NaN
# 2  Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                        Toto      NaN         NaN
# 4                                         NaN      NaN         NaN
#
#   Nationality Original name Name order                   name  height_cm  \
# 0         NaN           NaN        NaN  Jean-François Blanchy        NaN
# 1         NaN           NaN        NaN         Arnaud Boetsch      183.0
# 2         NaN           NaN        NaN           Jean Borotra      183.0
# 3         NaN           NaN        NaN        Jacques Brugnon      168.0
# 4         NaN           NaN        NaN           Albert Canet        NaN
#
#    weight_kg
# 0        NaN
# 1       76.0
# 2       76.0
# 3       64.0
# 4        NaN

# %%
# Check that again
df[~df['Measurements'].str.contains('/', na=False) & df['Measurements'].notna()][['Measurements', 'height_cm', 'weight_kg']].head()
# Out:
#     Measurements  height_cm  weight_kg
# 87        178 cm      178.0        NaN
# 105       191 cm      191.0        NaN
# 165       120 kg        NaN      120.0
# 242       161 cm      161.0        NaN
# 243       161 cm      161.0        NaN

# %%
# Who the tallest olympic player ion the dataset?
df.sort_values('height_cm', ascending=False).head(5)
# Out:
#                                     Roles   Sex  \
# 89070   Competed in Olympic Games • Other  Male
# 5781            Competed in Olympic Games  Male
# 6978            Competed in Olympic Games  Male
# 89075           Competed in Olympic Games  Male
# 120266          Competed in Olympic Games  Male
#
#                             Full name        Used name  \
# 89070                        Yao•Ming         Yao•Ming
# 5781    Thomas Loren "Tommy"•Burleson   Tommy•Burleson
# 6978            Arvydas Romas•Sabonis  Arvydas•Sabonis
# 89075        Roberto•Dueñas Hernández   Roberto•Dueñas
# 120266                   Zhang•Zhaoxu     Zhang•Zhaoxu
#
#                                                      Born Died  \
# 89070   12 September 1980 in Xuhui District, Shanghai ...  NaN
# 5781    24 February 1952 in Crossnore, North Carolina ...  NaN
# 6978             19 December 1964 in Kaunas, Kaunas (LTU)  NaN
# 89075             1 November 1975 in Madrid, Madrid (ESP)  NaN
# 120266        18 November 1987 in Binzhou, Shandong (CHN)  NaN
#
#                                NOC  athlete_id     Measurements  \
# 89070   People's Republic of China       89782  226 cm / 141 kg
# 5781                 United States        5804  223 cm / 102 kg
# 6978        Lithuania Soviet Union        7013  223 cm / 122 kg
# 89075                        Spain       89787  221 cm / 137 kg
# 120266  People's Republic of China      122147  221 cm / 110 kg
#
#                                              Affiliations Nick/petnames  \
# 89070   Shanghai Sharks, Shanghai (CHN) / Houston Rock...           NaN
# 5781                     NC State Wolfpack, Raleigh (USA)           NaN
# 6978    Žalgiris Kaunas, Kaunas (LTU) / Real Madrid, M...         Sabas
# 89075                       FC Barcelona, Barcelona (ESP)           NaN
# 120266                    Shanghai Sharks, Shanghai (CHN)           NaN
#
#        Title(s)                                   Other names Nationality  \
# 89070       NaN                                           NaN         NaN
# 5781        NaN                                           NaN         NaN
# 6978        NaN  Arvidas Romas Sabonis, Арвидас Ромас Сабонис   Lithuania
# 89075       NaN                                           NaN         NaN
# 120266      NaN                                           NaN         NaN
#
#        Original name Name order             name  height_cm  weight_kg
# 89070            姚•明   Oriental         Yao Ming      226.0      141.0
# 5781             NaN        NaN   Tommy Burleson      223.0      102.0
# 6978             NaN        NaN  Arvydas Sabonis      223.0      122.0
# 89075            NaN        NaN   Roberto Dueñas      221.0      137.0
# 120266          张•兆旭   Oriental     Zhang Zhaoxu      221.0      110.0

# %% [markdown]
# ## Parse out date from `Born` & `Died` Column

# %%
"""
    r'(\d+ \w+ \d{4}|\d{4})'
    \d+ -> match regex for 1 digit or more
    \w+ -> match regex for word 1 or more
    \d{4} -> match regex for 4 digit
"""

date_pattern = r'(\d+ \w+ \d{4}|\d{4})'
df['born_date'] = df['Born'].str.extract(date_pattern)
df['born_date'] = pd.to_datetime(df['born_date'], errors='coerce')

df['died_date'] = df['Died'].str.extract(date_pattern)
df['died_date'] = pd.to_datetime(df['died_date'], errors='coerce')

# %%
# df[~df['Born'].str.match(date_pattern, na=False) & df['Born'].notna()].head(5) For checking pattern

# %%
# Who the tallest male olympian player born in 2001?
df[(df['born_date'].dt.year==2001) & (df['Sex']=='Male')].sort_values('height_cm', ascending=False).head(1)
# Out:
#                             Roles   Sex                 Full name  \
# 140676  Competed in Olympic Games  Male  Gennaro Alberto•Di Mauro
#
#                Used name                                             Born  \
# 140676  Gennaro•Di Mauro  8 November 2001 in Massa di Somma, Napoli (ITA)
#
#        Died    NOC  athlete_id Measurements           Affiliations  ...  \
# 140676  NaN  Italy      144189       210 cm  CC Aniene, Roma (ITA)  ...
#
#        Title(s) Other names Nationality Original name Name order  \
# 140676      NaN         NaN         NaN           NaN        NaN
#
#                     name height_cm  weight_kg  born_date died_date
# 140676  Gennaro Di Mauro     210.0        NaN 2001-11-08       NaT
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Parse out city, region, and country from `Born` Column

# %%
location_pattern = r'in ([\w\s-]+), ([\w\s]+) \((\w+)\)'
df['Born'].str.extract(location_pattern, expand=True)
# Out:
#                    0                1    2
# 0           Bordeaux          Gironde  FRA
# 1             Meulan         Yvelines  FRA
# 2                NaN              NaN  NaN
# 3        Paris VIIIe            Paris  FRA
# 4         Wandsworth          England  GBR
# ...              ...              ...  ...
# 145495         Serov       Sverdlovsk  RUS
# 145496           NaN              NaN  NaN
# 145497        Kotlas      Arkhangelsk  RUS
# 145498           NaN              NaN  NaN
# 145499  Dulwich Hill  New South Wales  AUS
#
# [145500 rows x 3 columns]

# %%
df[['born_city', 'born_region', 'born_country']] = df['Born'].str.extract(location_pattern, expand=True)

# %%
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                                Full name  \
# 0  François Joseph Marie Antoine "Jean-François"•Blanchy
# 1                                Arnaud Benjamin•Boetsch
# 2                            Jean Laurent Robert•Borotra
# 3                   Jacques Marie Stanislas Jean•Brugnon
# 4                                     Henry Albert•Canet
#
#                Used name  \
# 0  Jean-François•Blanchy
# 1         Arnaud•Boetsch
# 2           Jean•Borotra
# 3        Jacques•Brugnon
# 4           Albert•Canet
#
#                                                      Born  \
# 0             12 December 1886 in Bordeaux, Gironde (FRA)
# 1                  1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiques (FRA)
# 3                 11 May 1895 in Paris VIIIe, Paris (FRA)
# 4              17 April 1878 in Wandsworth, England (GBR)
#
#                                                               Died     NOC  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-Atlantiques (FRA)  France
# 1                                                              NaN  France
# 2              17 July 1994 in Arbonne, Pyrénées-Atlantiques (FRA)  France
# 3                            20 March 1978 in Monaco, Monaco (MON)  France
# 4                          25 July 1930 in Paris VIIe, Paris (FRA)  France
#
#    athlete_id    Measurements                         Affiliations  ...  \
# 0           1             NaN                                  NaN  ...
# 1           2  183 cm / 76 kg   Racing Club de France, Paris (FRA)  ...
# 2           3  183 cm / 76 kg                     TCP, Paris (FRA)  ...
# 3           4  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)  ...
# 4           5             NaN                     TCP, Paris (FRA)  ...
#
#   Original name Name order                   name height_cm weight_kg  \
# 0           NaN        NaN  Jean-François Blanchy       NaN       NaN
# 1           NaN        NaN         Arnaud Boetsch     183.0      76.0
# 2           NaN        NaN           Jean Borotra     183.0      76.0
# 3           NaN        NaN        Jacques Brugnon     168.0      64.0
# 4           NaN        NaN           Albert Canet       NaN       NaN
#
#    born_date  died_date    born_city  born_region born_country
# 0 1886-12-12 1960-10-02     Bordeaux      Gironde          FRA
# 1 1969-04-01        NaT       Meulan     Yvelines          FRA
# 2 1898-08-13 1994-07-17          NaN          NaN          NaN
# 3 1895-05-11 1978-03-20  Paris VIIIe        Paris          FRA
# 4 1878-04-17 1930-07-25   Wandsworth      England          GBR
#
# [5 rows x 24 columns]

# %%
# What city born the athlete the most?
df['born_city'].value_counts().head(5)
# Out:
# Budapest        1378
# Oslo             708
# Stockholm        629
# Toronto          579
# Buenos Aires     538
# Name: born_city, dtype: int64

# %% [markdown]
# ## Get rid extras columns

# %%
df.head(5)
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                                Full name  \
# 0  François Joseph Marie Antoine "Jean-François"•Blanchy
# 1                                Arnaud Benjamin•Boetsch
# 2                            Jean Laurent Robert•Borotra
# 3                   Jacques Marie Stanislas Jean•Brugnon
# 4                                     Henry Albert•Canet
#
#                Used name  \
# 0  Jean-François•Blanchy
# 1         Arnaud•Boetsch
# 2           Jean•Borotra
# 3        Jacques•Brugnon
# 4           Albert•Canet
#
#                                                      Born  \
# 0             12 December 1886 in Bordeaux, Gironde (FRA)
# 1                  1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiques (FRA)
# 3                 11 May 1895 in Paris VIIIe, Paris (FRA)
# 4              17 April 1878 in Wandsworth, England (GBR)
#
#                                                               Died     NOC  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-Atlantiques (FRA)  France
# 1                                                              NaN  France
# 2              17 July 1994 in Arbonne, Pyrénées-Atlantiques (FRA)  France
# 3                            20 March 1978 in Monaco, Monaco (MON)  France
# 4                          25 July 1930 in Paris VIIe, Paris (FRA)  France
#
#    athlete_id    Measurements                         Affiliations  \
# 0           1             NaN                                  NaN
# 1           2  183 cm / 76 kg   Racing Club de France, Paris (FRA)
# 2           3  183 cm / 76 kg                     TCP, Paris (FRA)
# 3           4  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)
# 4           5             NaN                     TCP, Paris (FRA)
#
#                                 Nick/petnames Title(s) Other names  \
# 0                                         NaN      NaN         NaN
# 1                                         NaN      NaN         NaN
# 2  Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                        Toto      NaN         NaN
# 4                                         NaN      NaN         NaN
#
#   Nationality Original name Name order                   name  height_cm  \
# 0         NaN           NaN        NaN  Jean-François Blanchy        NaN
# 1         NaN           NaN        NaN         Arnaud Boetsch      183.0
# 2         NaN           NaN        NaN           Jean Borotra      183.0
# 3         NaN           NaN        NaN        Jacques Brugnon      168.0
# 4         NaN           NaN        NaN           Albert Canet        NaN
#
#    weight_kg  born_date  died_date    born_city born_region born_country
# 0        NaN 1886-12-12 1960-10-02     Bordeaux     Gironde          FRA
# 1       76.0 1969-04-01        NaT       Meulan    Yvelines          FRA
# 2       76.0 1898-08-13 1994-07-17          NaN         NaN          NaN
# 3       64.0 1895-05-11 1978-03-20  Paris VIIIe       Paris          FRA
# 4        NaN 1878-04-17 1930-07-25   Wandsworth     England          GBR

# %%
df.columns
# Out:
# Index(['Roles', 'Sex', 'Full name', 'Used name', 'Born', 'Died', 'NOC',
#        'athlete_id', 'Measurements', 'Affiliations', 'Nick/petnames',
#        'Title(s)', 'Other names', 'Nationality', 'Original name', 'Name order',
#        'name', 'height_cm', 'weight_kg', 'born_date', 'died_date', 'born_city',
#        'born_region', 'born_country'],
#       dtype='object')

# %%
df_clean = df[
    [
        "athlete_id",
        "name",
        "Sex",
        "born_date",
        "born_city",
        "born_region",
        "born_country",
        "died_date",
        "NOC",
        "height_cm",
        "weight_kg"
    ]
]

# %%
df_clean.columns = df_clean.columns.str.casefold()

# %%
df_clean
# Out:
#         athlete_id                   name     sex  born_date     born_city  \
# 0                1  Jean-François Blanchy    Male 1886-12-12      Bordeaux
# 1                2         Arnaud Boetsch    Male 1969-04-01        Meulan
# 2                3           Jean Borotra    Male 1898-08-13           NaN
# 3                4        Jacques Brugnon    Male 1895-05-11   Paris VIIIe
# 4                5           Albert Canet    Male 1878-04-17    Wandsworth
# ...            ...                    ...     ...        ...           ...
# 145495      149222      Polina Luchnikova  Female 2002-01-30         Serov
# 145496      149223    Valeriya Merkusheva  Female 1999-09-20           NaN
# 145497      149224        Yuliya Smirnova  Female 1998-05-08        Kotlas
# 145498      149225         André Foussard    Male 1899-05-19           NaN
# 145499      149814          Bill Phillips    Male 1913-07-15  Dulwich Hill
#
#             born_region born_country  died_date        noc  height_cm  \
# 0               Gironde          FRA 1960-10-02     France        NaN
# 1              Yvelines          FRA        NaT     France      183.0
# 2                   NaN          NaN 1994-07-17     France      183.0
# 3                 Paris          FRA 1978-03-20     France      168.0
# 4               England          GBR 1930-07-25     France        NaN
# ...                 ...          ...        ...        ...        ...
# 145495       Sverdlovsk          RUS        NaT        ROC      167.0
# 145496              NaN          NaN        NaT        ROC      168.0
# 145497      Arkhangelsk          RUS        NaT        ROC      163.0
# 145498              NaN          NaN 1986-03-18     France      166.0
# 145499  New South Wales          AUS 2003-10-20  Australia        NaN
#
#         weight_kg
# 0             NaN
# 1            76.0
# 2            76.0
# 3            64.0
# 4             NaN
# ...           ...
# 145495       61.0
# 145496       65.0
# 145497       55.0
# 145498        NaN
# 145499        NaN
#
# [145500 rows x 11 columns]

# %%
df_clean.to_csv('Olympics-Dataset/clean-data/bios.csv', index=False)

# %% [markdown]
# # Clean the Result File

# %%
results = pd.read_csv('Olympics-Dataset/results/results.csv')
# Out:
# /tmp/ipykernel_21160/3489496698.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   results = pd.read_csv('Olympics-Dataset/results/results.csv')

# %%
results.tail()
# Out:
#                        Games                          Event    Team   Pos  \
# 308403  2022 Winter Olympics         Singles, Men (Olympic)     NaN  26.0
# 308404  2022 Winter Olympics        Slalom, Women (Olympic)     NaN  28.0
# 308405  2022 Winter Olympics          Team, Mixed (Olympic)  Sweden    13
# 308406  2022 Winter Olympics  Giant Slalom, Women (Olympic)     NaN   DNF
# 308407  2022 Winter Olympics        Slalom, Women (Olympic)     NaN  24.0
#
#        Medal                    As  athlete_id  NOC              Discipline  \
# 308403   NaN         Marián Skupek      148983  SVK                    Luge
# 308404   NaN         Elsa Fermbäck      148984  SWE  Alpine Skiing (Skiing)
# 308405   NaN         Hilma Lövblom      148985  SWE  Alpine Skiing (Skiing)
# 308406   NaN         Hilma Lövblom      148985  SWE  Alpine Skiing (Skiing)
# 308407   NaN  Charlotta Säfvenberg      148986  NaN                     NaN
#
#        Nationality  Unnamed: 7
# 308403         NaN         NaN
# 308404         NaN         NaN
# 308405         NaN         NaN
# 308406         NaN         NaN
# 308407         NaN         NaN

# %%
df = results.copy()

# %% [markdown]
# ### What we will doing for results file
# - [x] Clean the position column
# - [x] Split the Event into Event Type & Gender
# - [x] Extract Games columns into Year and Season
# - [x] Remove duplicates
# - [x] Remove unneeded Columns

# %% [markdown]
# ## Clean the position column

# %%
df['position'] = df['Pos'].str.extract(r'(\d+)')

# %% [markdown]
# ## Split the Event into Event Type & Gender

# %%
df[['event_type', 'gender_competing']] = df['Event'].str.extract(r'([\w\s]+), (\w+)', expand=True)

# %% [markdown]
# ## Extract Games columns into Year and Season

# %%
df[['year_compete', 'season_compete']] = df['Games'].str.extract(r'(\d+) (\w+)')
df['year_compete'][df['year_compete'] == '89'] = 1889
df['year_compete'] = pd.to_numeric(df['year_compete'])
# Out:
# /tmp/ipykernel_21160/307254217.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year_compete'][df['year_compete'] == '89'] = 1889

# %% [markdown]
# ## Remove unneeded Columns

# %%
df.head(10)
# Out:
#                   games                     event                team  pos  \
# 0  1912 Summer Olympics    Singles, Men (Olympic)                 NaN  =17
# 1  1912 Summer Olympics    Doubles, Men (Olympic)      Jean Montariol  DNS
# 2  1920 Summer Olympics    Singles, Men (Olympic)                 NaN  =32
# 3  1920 Summer Olympics  Doubles, Mixed (Olympic)     Jeanne Vaussard   =8
# 4  1920 Summer Olympics    Doubles, Men (Olympic)     Jacques Brugnon    4
# 5  1996 Summer Olympics    Singles, Men (Olympic)                 NaN  =17
# 6  1996 Summer Olympics    Doubles, Men (Olympic)     Guillaume Raoux  =17
# 7  1924 Summer Olympics    Singles, Men (Olympic)                 NaN    4
# 8  1924 Summer Olympics  Doubles, Mixed (Olympic)  Marguerite Billout  =15
# 9  1924 Summer Olympics    Doubles, Men (Olympic)        René Lacoste    3
#
#     medal                     as  athlete_id  noc discipline nationality  \
# 0     NaN  Jean-François Blanchy           1  FRA     Tennis         NaN
# 1     NaN  Jean-François Blanchy           1  FRA     Tennis         NaN
# 2     NaN  Jean-François Blanchy           1  FRA     Tennis         NaN
# 3     NaN  Jean-François Blanchy           1  FRA     Tennis         NaN
# 4     NaN  Jean-François Blanchy           1  FRA     Tennis         NaN
# 5     NaN         Arnaud Boetsch           2  FRA     Tennis         NaN
# 6     NaN         Arnaud Boetsch           2  FRA     Tennis         NaN
# 7     NaN           Jean Borotra           3  FRA     Tennis         NaN
# 8     NaN           Jean Borotra           3  FRA     Tennis         NaN
# 9  Bronze           Jean Borotra           3  FRA     Tennis         NaN
#
#    unnamed: 7 position event_type gender_competing  year_compete  \
# 0         NaN       17    Singles              Men          1912
# 1         NaN      NaN    Doubles              Men          1912
# 2         NaN       32    Singles              Men          1920
# 3         NaN        8    Doubles            Mixed          1920
# 4         NaN        4    Doubles              Men          1920
# 5         NaN       17    Singles              Men          1996
# 6         NaN       17    Doubles              Men          1996
# 7         NaN        4    Singles              Men          1924
# 8         NaN       15    Doubles            Mixed          1924
# 9         NaN        3    Doubles              Men          1924
#
#   season_compete
# 0         Summer
# 1         Summer
# 2         Summer
# 3         Summer
# 4         Summer
# 5         Summer
# 6         Summer
# 7         Summer
# 8         Summer
# 9         Summer

# %%
df.columns = df.columns.str.casefold()

# %%
df = df.drop_duplicates(subset='athlete_id').reset_index()

# %%
df_clean = df[
    [
        "athlete_id",
        "year_compete",
        "season_compete",
        "discipline",
        "event_type",
        "gender_competing",
        "position",
        "team",
        "medal",
    ]
]

# %%
df_clean
# Out:
#         athlete_id  year_compete season_compete               discipline  \
# 0                1          1912         Summer                   Tennis
# 1                2          1996         Summer                   Tennis
# 2                3          1924         Summer                   Tennis
# 3                4          1920         Summer                   Tennis
# 4                5          1912         Summer                   Tennis
# ...            ...           ...            ...                      ...
# 145257      148982          2022         Winter  Ice Hockey (Ice Hockey)
# 145258      148983          2022         Winter                     Luge
# 145259      148984          2022         Winter   Alpine Skiing (Skiing)
# 145260      148985          2022         Winter   Alpine Skiing (Skiing)
# 145261      148986          2022         Winter                      NaN
#
#         event_type gender_competing position      team   medal
# 0          Singles              Men       17       NaN     NaN
# 1          Singles              Men       17       NaN     NaN
# 2          Singles              Men        4       NaN     NaN
# 3          Singles              Men        9       NaN     NaN
# 4          Singles              Men       17       NaN     NaN
# ...            ...              ...      ...       ...     ...
# 145257  Ice Hockey              Men        3  Slovakia  Bronze
# 145258     Singles              Men       26       NaN     NaN
# 145259      Slalom            Women       28       NaN     NaN
# 145260        Team            Mixed       13    Sweden     NaN
# 145261      Slalom            Women       24       NaN     NaN
#
# [145262 rows x 9 columns]

# %%
df_clean.to_csv('Olympics-Dataset/clean-data/results.csv', index=False)

# %% [markdown]
# # Merged two dataframe

# %%
bios_cleaned = pd.read_csv('Olympics-Dataset/clean-data/bios.csv')
results_cleaned = pd.read_csv('Olympics-Dataset/clean-data/results.csv')

# %%
Olympic_Athletes = pd.merge(right=results_cleaned, left=bios_cleaned, on='athlete_id', how='inner')

# %%
Olympic_Athletes
# Out:
#         athlete_id                   name     sex   born_date    born_city  \
# 0                1  Jean-François Blanchy    Male  1886-12-12     Bordeaux
# 1                2         Arnaud Boetsch    Male  1969-04-01       Meulan
# 2                3           Jean Borotra    Male  1898-08-13          NaN
# 3                4        Jacques Brugnon    Male  1895-05-11  Paris VIIIe
# 4                5           Albert Canet    Male  1878-04-17   Wandsworth
# ...            ...                    ...     ...         ...          ...
# 145257      148982            Peter Zuzin    Male  1990-09-04       Zvolen
# 145258      148983          Marián Skupek    Male  2001-07-12      Gelnica
# 145259      148984          Elsa Fermbäck  Female  1998-03-28     Vemdalen
# 145260      148985          Hilma Lövblom  Female  2000-08-16         Täby
# 145261      148986   Charlotta Säfvenberg  Female  1994-10-07   Kungsbacka
#
#             born_region born_country   died_date       noc  height_cm  \
# 0               Gironde          FRA  1960-10-02    France        NaN
# 1              Yvelines          FRA         NaN    France      183.0
# 2                   NaN          NaN  1994-07-17    France      183.0
# 3                 Paris          FRA  1978-03-20    France      168.0
# 4               England          GBR  1930-07-25    France        NaN
# ...                 ...          ...         ...       ...        ...
# 145257  Banská Bystrica          SVK         NaN  Slovakia      183.0
# 145258           Košice          SVK         NaN  Slovakia      196.0
# 145259         Jämtland          SWE         NaN    Sweden        NaN
# 145260        Stockholm          SWE         NaN    Sweden        NaN
# 145261          Halland          SWE         NaN    Sweden        NaN
#
#         weight_kg  year_compete season_compete               discipline  \
# 0             NaN          1912         Summer                   Tennis
# 1            76.0          1996         Summer                   Tennis
# 2            76.0          1924         Summer                   Tennis
# 3            64.0          1920         Summer                   Tennis
# 4             NaN          1912         Summer                   Tennis
# ...           ...           ...            ...                      ...
# 145257       81.0          2022         Winter  Ice Hockey (Ice Hockey)
# 145258      108.0          2022         Winter                     Luge
# 145259        NaN          2022         Winter   Alpine Skiing (Skiing)
# 145260        NaN          2022         Winter   Alpine Skiing (Skiing)
# 145261        NaN          2022         Winter                      NaN
#
#         event_type gender_competing  position      team   medal
# 0          Singles              Men      17.0       NaN     NaN
# 1          Singles              Men      17.0       NaN     NaN
# 2          Singles              Men       4.0       NaN     NaN
# 3          Singles              Men       9.0       NaN     NaN
# 4          Singles              Men      17.0       NaN     NaN
# ...            ...              ...       ...       ...     ...
# 145257  Ice Hockey              Men       3.0  Slovakia  Bronze
# 145258     Singles              Men      26.0       NaN     NaN
# 145259      Slalom            Women      28.0       NaN     NaN
# 145260        Team            Mixed      13.0    Sweden     NaN
# 145261      Slalom            Women      24.0       NaN     NaN
#
# [145262 rows x 19 columns]

# %%
Olympic_Athletes.to_csv('Olympics-Dataset/clean-data/Olympic_Athletes.csv', index=False)
